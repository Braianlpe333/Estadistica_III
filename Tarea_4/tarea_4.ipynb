# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Investigar mas transformaciones
a = cv2.cvtColor(cv2.imread("train/Black-grass/0ace21089.png"), cv2.COLOR_BGR2LAB)
#plt.imshow(a[:,:,1])

# %%
a = cv2.cvtColor(cv2.imread("train/Cleavers/005b4a3e3.png"), cv2.COLOR_BGR2LAB)
b=a[:,:,1]
plt.imshow(a[:,:,1], cmap='gray')
b.min()
fig,x = plt.subplots(1,1, figsize=(10,10))
_=plt.hist(b.ravel(), bins=20)

# %%
a
# Out:
# array([[[141, 138, 135],
#         [140, 136, 134],
#         [140, 137, 135],
#         ...,
#         [132, 126, 122],
#         [122, 117, 115],
#         [128, 125, 123]],
#
#        [[142, 140, 137],
#         [140, 137, 135],
#         [140, 137, 135],
#         ...,
#         [127, 123, 119],
#         [129, 125, 123],
#         [134, 131, 128]],
#
#        [[148, 146, 144],
#         [142, 139, 138],
#         [141, 139, 138],
#         ...,
#         [130, 127, 123],
#         [132, 128, 126],
#         [133, 130, 128]],
#
#        ...,
#
#        [[ 79,  52,  24],
#         [ 79,  52,  26],
#         [ 84,  58,  37],
#         ...,
#         [ 77,  54,  34],
#         [ 85,  62,  39],
#         [ 88,  64,  40]],
#
#        [[ 81,  54,  25],
#         [ 80,  53,  25],
#         [ 79,  53,  26],
#         ...,
#         [ 75,  55,  36],
#         [ 79,  58,  36],
#         [ 83,  60,  35]],
#
#        [[ 84,  56,  29],
#         [ 86,  60,  34],
#         [ 82,  57,  31],
# ...
