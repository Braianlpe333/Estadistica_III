# %%
# !pip install sounddevice
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import math
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
#Copiamos el codigo dado en la tarea y se calculan las derivadas parciales para el gradiente descendiente

# %%
def y_predict(a,b,c,d,x):
    return a * np.sin(b*x + c) + d

def gradient_descent(x, y, lr, batch, epochs):
	n = len(x)
	rsl = []
	a = random.random()
	b = random.random()
	c = random.random()
	d = 0
	for i in range(epochs):
		a_gradiente = 0
		b_gradiente = 0
		c_gradiente = 0
		d_gradiente = 0
		error = 0
		e=0
		for m in range(batch):
			ix = int(random.uniform(0,n))
			y_predic = y_predict(a,b,c,d,x[ix])
			error = y[ix] - y_predic
			e += error**2
			a_gradiente += 2 * error * -1.0*(np.sin(b * x[ix] + c))
			b_gradiente += 2 * error * -1.0*(np.cos(b * x[ix] + c) * x[ix])
			c_gradiente += 2 * error * -1.0*(np.cos(b * x[ix] + c))
			d_gradiente += 2 * error
            
		a -= lr * a_gradiente/batch
		b -= lr * b_gradiente/batch
		c -= lr * c_gradiente/batch
        
		error = error/batch
		rsl.append([a,b,c,error])
		print(f"error:{e} period:{b} amplitude:{a} constant:{c}")
	return rsl, a, b, c

# %%
#Importamos los datos de la señal dada por la tarea

# %%
data = pd.read_csv("senal.csv")

# %%
#y los separamos tanto en x como en y para poder hacer la aproximacion

# %%
x = data["x"].values
y = data["y"].values

# %%
#Empezamos entonces a evaluar con cada uno de los Epochs Solicitados:

# %%
#Con 10 Epochs

# %%
lr = 0.01
batch = 500
epochs = 10

resultados, a, b, c = gradient_descent(x,y,lr, batch,epochs)
# Out:
# error:2459.019459500196 period:0.8020095454793789 amplitude:0.8486456339013867 constant:0.682328280310078
# error:2727.301887296447 period:0.8120413263480193 amplitude:0.8257067910182545 constant:0.6904400443566926
# error:2642.6161973123258 period:0.8169421950806468 amplitude:0.8066538514207237 constant:0.6964717369271674
# error:2742.0069701930297 period:0.8286044924978829 amplitude:0.7851588813097217 constant:0.7058535340737009
# error:2598.4259119074695 period:0.8358413875642411 amplitude:0.7643367691141871 constant:0.7130415641743889
# error:2531.656977808693 period:0.8456736118043964 amplitude:0.7443571267950065 constant:0.7215124718008764
# error:2682.996101941076 period:0.858067306364689 amplitude:0.7240478798691175 constant:0.7316049229918994
# error:2593.912714624529 period:0.8662674050813597 amplitude:0.7056585791227856 constant:0.7398444695218503
# error:2455.488322332583 period:0.8739553285209386 amplitude:0.6889898366541776 constant:0.7477691331859817
# ...

# %%
plt.ylabel("y")
plt.plot(y)
ix=-1
plt.plot([y_predict(a,b,c,0,xi) for xi in x[:ix]])

# %%
#Con 400 Epochs

# %%
lr = 0.01
batch = 500
epochs = 400

resultados, a, b, c = gradient_descent(x,y,lr,batch,epochs)
# Out:
# error:2216.3399589308 period:0.3861806000493467 amplitude:0.332493247854465 constant:0.9499079305780384
# error:2266.838718092555 period:0.38328275640697057 amplitude:0.31764325714081504 constant:0.9495633884975008
# error:2150.716105440317 period:0.3807637127484937 amplitude:0.302862916478318 constant:0.9493382438951492
# error:2120.2816963940554 period:0.3774236603895701 amplitude:0.29173152495541843 constant:0.948867463503411
# error:2098.519351720113 period:0.3746218545383027 amplitude:0.2784565607796406 constant:0.9485235010452654
# error:2073.9559856533633 period:0.37191846899121395 amplitude:0.26402493847837954 constant:0.9480342769348107
# error:2100.492162246608 period:0.3684586287383552 amplitude:0.2511633983073456 constant:0.9473031568249364
# error:2109.2153587320863 period:0.36622570953218514 amplitude:0.23767782218061612 constant:0.9473318988993799
# error:2179.2113504377453 period:0.3624049472423393 amplitude:0.22463139137803984 constant:0.9464014702448096
# ...

# %%
plt.ylabel("y")
plt.plot(y)
ix=-1
plt.plot([y_predict(a,b,c,0,xi) for xi in x[:ix]])

# %%
#Con 1000 Epochs

# %%
lr = 0.01
batch = 500
epochs = 1000

resultados, a, b, c = gradient_descent(x,y,lr,batch,epochs)
# Out:
# error:2579.442051319261 period:0.5355477320112274 amplitude:0.720959187507229 constant:0.411859890156656
# error:2444.627173673034 period:0.5234016413905125 amplitude:0.7022095793544968 constant:0.4054450548420532
# error:2319.304572500257 period:0.512409366856854 amplitude:0.686046005355999 constant:0.4002630225600706
# error:2419.2614914375877 period:0.4995940647242717 amplitude:0.6697055368327884 constant:0.393563368111799
# error:2236.61173243432 period:0.4881176086097516 amplitude:0.6563483013356477 constant:0.38797864669295085
# error:2391.2737419042824 period:0.4735393500535322 amplitude:0.6370614632803127 constant:0.3800185091513197
# error:2486.9513100910626 period:0.4573846004189664 amplitude:0.6176201879672716 constant:0.37091002270135615
# error:2324.4060216022426 period:0.44283587531423435 amplitude:0.6013652311586544 constant:0.3634873048319851
# error:2392.9044754315123 period:0.42826612198027053 amplitude:0.5875543087293881 constant:0.35574885025572833
# ...

# %%
plt.ylabel("y")
plt.plot(y)
ix=-1
plt.plot([y_predict(a,b,c,0,xi) for xi in x[:ix]])

# %%
#Con 2000 Epochs

# %%
lr = 0.01
batch = 500
epochs = 2000

resultados, a, b, c = gradient_descent(x,y,lr,batch,epochs)
# Out:
# error:2054.508174341912 period:0.7911597502244279 amplitude:0.10572599938340674 constant:0.20565044791141548
# error:2066.3185642228977 period:0.7846718478163527 amplitude:0.09468407352245087 constant:0.2052079099424717
# error:2123.2746233228077 period:0.7767204981770696 amplitude:0.08197220315470811 constant:0.20353562523255408
# error:2144.765868488943 period:0.7680900258005635 amplitude:0.07205536987662559 constant:0.20182736651375996
# error:2023.908594011148 period:0.7600928199014205 amplitude:0.06194093823077014 constant:0.2001762784868061
# error:1841.654620490921 period:0.7523876987631012 amplitude:0.05473348907411807 constant:0.19869079189280406
# error:2039.5817834318245 period:0.7438007372241389 amplitude:0.04480714387022181 constant:0.19658273741553933
# error:2005.4954590276761 period:0.7353703803484611 amplitude:0.03768091909140438 constant:0.19495261230275324
# ...

# %%
plt.ylabel("y")
plt.plot(y)
ix=-1
plt.plot([y_predict(a,b,c,0,xi) for xi in x[:ix]])

# %%
#Podemos obervar entonces como entre mas epochs se tengan mucho mejor es la prediccion dada por el gradiente descendiente
#viendo como la ultima de 2000 epochs la aproximacion es casi perfecta con respecto a la señal origina.
#Pero haciendo pruebas tambien se ve como con una mayor tasa lr o learning grade se pueden obtener aproximaciones mucho mas rapidas
#de la señal dada
